# %% [markdown]
# ### READING PDF FILE

# %%
conda install -c conda-forge tabula-py
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula

# %% [markdown]
# ### EXTRACTING TABULAR DATA FROM PDF FILE

# %%
tables = tabula.read_pdf("Personal_statement.pdf", pages="all")

# %% [markdown]
# ### CONVERTING PDF TO CSV FILE

# %%
tabula.convert_into("Personal_statement.pdf", "Personal_statement.csv", output_format="csv", pages="2")

# %%
import pandas as pd

# %% [markdown]
# ### READING THE CSV FILE

# %%
pd.read_csv("Personal_statement.csv")
# Out:
#                                         RRSP 12345678  Unnamed: 1 Unnamed: 2  \
# 0                              Summary of Investments         NaN        NaN
# 1   Market Value Investment Book Value Account Number         NaN      Price
# 2           ABC082 ABC Funds Foreign Equity FE  12367         NaN     $13.50
# 3          ABC682 ABC Funds Foreign Equity DSC  12367         NaN     $13.50
# 4             EFG1800 EFG Investments Bond FE  789456         NaN     $19.63
# 5      HIJ1583 HIJ Company Canadian Equity FE 2346543         NaN     $17.51
# 6           QRS305 QRS Funds Money Market FE  3214569         NaN     $10.00
# 7                                                 NaN         NaN        NaN
# 8   DSC, LSC or LL: This investment may be subject...         NaN        NaN
# 9   charge is usually based on the net asset value...         NaN        NaN
# 10  amount you receive for the units/shares. Defer...         NaN        NaN
# ...

# %% [markdown]
# ### READING THE GIVEN XLS FILE

# %%
df = pd.read_excel("Sample Bank Reconciliation.xls")

# %%
df
# Out:
#     Unnamed: 0                       BANK RECONCILIATION           Unnamed: 2  \
# 0          NaN                                       NaN                  NaN
# 1          NaN                                 BANK NAME             XYZ BANK
# 2          NaN                                       NaN                  NaN
# 3          NaN                            ACCOUNT NUMBER           0000000000
# 4          NaN                                       NaN                  NaN
# 5          NaN                             MONTH ENDING   2009-03-31 00:00:00
# 6          NaN                                       NaN
# 7          NaN                                       NaN                  NaN
# 8          NaN                BALANCE PER BANK STATEMENT                  NaN
# 9          NaN                                       NaN                  NaN
# 10         NaN                                       NaN                  NaN
# ...

# %% [markdown]
# ### CONVERT XLS TO CSV

# %%
read_file = pd.read_excel ("Sample Bank Reconciliation.xls")
read_file.to_csv ("Sample Bank Reconciliation.csv", 
                  index = None,
                  header=True)
df = pd.DataFrame(pd.read_csv("Sample Bank Reconciliation.csv"))
  
df
# Out:
#     Unnamed: 0                       BANK RECONCILIATION           Unnamed: 2  \
# 0          NaN                                       NaN                  NaN
# 1          NaN                                 BANK NAME             XYZ BANK
# 2          NaN                                       NaN                  NaN
# 3          NaN                            ACCOUNT NUMBER           0000000000
# 4          NaN                                       NaN                  NaN
# 5          NaN                             MONTH ENDING   2009-03-31 00:00:00
# 6          NaN                                       NaN
# 7          NaN                                       NaN                  NaN
# 8          NaN                BALANCE PER BANK STATEMENT                  NaN
# 9          NaN                                       NaN                  NaN
# 10         NaN                                       NaN                  NaN
# ...

# %% [markdown]
# ### FILLING NaN WITH " "

# %%
df=df.fillna(" ")
df
# Out:
#    Unnamed: 0                       BANK RECONCILIATION           Unnamed: 2  \
# 0
# 1                                             BANK NAME             XYZ BANK
# 2
# 3                                        ACCOUNT NUMBER           0000000000
# 4
# 5                                         MONTH ENDING   2009-03-31 00:00:00
# 6
# 7
# 8                            BALANCE PER BANK STATEMENT
# 9
# 10
# 11                                 Deposits in transit:
# 12
# 13
# 14
# 15                                  Outstanding Checks:
# 16
# 17
# 18
# 19
# 20
# 21
# 22
# 23                                ADJUSTED BANK BALANCE
# 24
# 25
# 26                           BALANCE PER GENERAL LEDGER
# 27
# 28
# 29                                Deposits not recorded
# 30
# 31
# 32
# 33
# 34             Checks/Electronic Transfers not Recorded
# 35
# 36
# 37
# 38
# 39                              ADJUSTED LEDGER BALANCE
# 40
# 41
# 42
# 43
# 44
# 45
# 46
# ...

# %%
df1=pd.read_csv("Summary of Investment.csv")
del df1['Unnamed: 1']
del df1['Unnamed: 6']
df1=df1.fillna(" ")
df1
# Out:
#   Market Value Investment Book Value Account Number   Price      Units  \
# 0         ABC082 ABC Funds Foreign Equity FE  12367  $13.50    204.175
# 1        ABC682 ABC Funds Foreign Equity DSC  12367  $13.50    924.551
# 2           EFG1800 EFG Investments Bond FE  789456  $19.63    771.708
# 3    HIJ1583 HIJ Company Canadian Equity FE 2346543  $17.51  1,562.450
# 4         QRS305 QRS Funds Money Market FE  3214569  $10.00    210.532
# 5
#
#    Unnamed: 4 Market Value Oct 1, 2016 Dec 31, 2016
# 0   $2,002.36                $2,765.66    $2,756.36
# 1  $10,056.79               $12,523.62   $12,481.44
# 2  $14,956.23               $15,128.26   $15,148.63
# 3  $21,562.45               $27,309.82   $27,358.50
# 4   $2,105.32                $2,100.10    $2,105.32
# 5  $50,683.15               $59,827.46   $59,850.25

# %%
df2=pd.read_csv("EFG Investment Bond Fund.csv")
df2=df2.fillna(" ")
df2
# Out:
#      Trade Date               Activity Gross Amount Unit Price    Units  \
# 0   Oct 1, 2016        Opening Balance
# 1  Oct 31, 2016  Dividend Reinvestment       $10.35     $19.60  0.52806
# 2  Nov 30, 2016  Dividend Reinvestment       $10.29     $19.65  0.52366
# 3  Dec 30, 2016  Dividend Reinvestment       $10.31     $19.63  0.52522
# 4  Dec 31, 2016        Closing Balance
#
#    Total Units
# 0      770.131
# 1      770.659
# 2      771.183
# 3      771.708
# 4      771.708

# %%
df3=pd.read_csv("QRS Funds Money Market FE.csv")
df3=df3.fillna(" ")
df3
# Out:
#      Trade Date               Activity Gross Amount Unit Price  Units  \
# 0   Oct 1, 2016        Opening Balance
# 1  Oct 31, 2016  Dividend Reinvestment        $1.74     $10.00  0.174
# 2  Nov 30, 2016  Dividend Reinvestment        $1.74     $10.00  0.174
# 3  Dec 30, 2016  Dividend Reinvestment        $1.74     $10.00  0.174
# 4  Dec 31, 2016        Closing Balance
#
#    Total Units
# 0      210.010
# 1      210.184
# 2      210.358
# 3      210.532
# 4      210.532

# %% [markdown]
# ### CONNECTING TO DATABASE

# %%
import mysql.connector

mydb = mysql.connector.connect(
host="localhost",
user="root",
password="aatu1212",
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM assesment1.`sample bank reconciliation`;")

myresult = mycursor.fetchall()

for x in myresult:
 print(x)
# Out:
# ('', '', '', '', '', '')
# ('', 'BANK NAME', 'XYZ BANK', '', '', '')
# ('', '', '', '', '', '')
# ('', 'ACCOUNT NUMBER', '0000000000', '', '', '')
# ('', '', '', '', '', '')
# ('', 'MONTH ENDING ', '2009-03-31 00:00:00', '', '', '')
# ('', '', ' ', '', '', '')
# ('', '', '', '', '', '')
# ('', 'BALANCE PER BANK STATEMENT', '', '2009-03-31 00:00:00', ' ', '100000')
# ('', '', '', '', '', '')
# ('', '', '', '', '', '')
# ('', '   Deposits in transit:', '', '', '', '')
# ('', '', '', '', '2005-03-31 00:00:00', '25000')
# ('', '', '', '', '', '')
# ('', '', '', '', '', '')
# ('', '   Outstanding Checks:', '', '', '', '')
# ('', '', '', '', 'Check # 1234', '-100')
# ('', '', '', '', 'Check # 1235', '-25')
# ('', '', '', '', 'Check # 1236', '-75')
# ('', '', '', '', 'Check # 1237', '-50')
# ('', '', '', '', '', '')
# ('', '', '', '', '', '')
# ('', '', '', '', '', '')
# ('', 'ADJUSTED BANK BALANCE', '', ' ', '', '124750')
# ('', '', '', '', '', '')
# ('', '', '', '', '', '')
# ...

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="aatu1212",
)
 
mycursor = mydb.cursor()
 
mycursor.execute("SELECT * FROM assesment1.`efg investment bond fund`;")
 
myresult = mycursor.fetchall()
 
for x in myresult:
  print(x)
# Out:
# ('Oct 1, 2016', 'Opening Balance', '', '', '', 770.131)
# ('Oct 31, 2016', 'Dividend Reinvestment', '$10.35', '$19.60', '0.52806', 770.659)
# ('Nov 30, 2016', 'Dividend Reinvestment', '$10.29', '$19.65', '0.52366', 771.183)
# ('Dec 30, 2016', 'Dividend Reinvestment', '$10.31', '$19.63', '0.52522', 771.708)
# ('Dec 31, 2016', 'Closing Balance', '', '', '', 771.708)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="aatu1212",
)
 
mycursor = mydb.cursor()
 
mycursor.execute("SELECT * FROM assesment1.`qrs funds money market fe`;")
 
myresult = mycursor.fetchall()
 
for x in myresult:
  print(x)
# Out:
# ('Oct 1, 2016', 'Opening Balance', '', '', '', 210.01)
# ('Oct 31, 2016', 'Dividend Reinvestment', '$1.74', '$10.00', '0.174', 210.184)
# ('Nov 30, 2016', 'Dividend Reinvestment', '$1.74', '$10.00', '0.174', 210.358)
# ('Dec 30, 2016', 'Dividend Reinvestment', '$1.74', '$10.00', '0.174', 210.532)
# ('Dec 31, 2016', 'Closing Balance', '', '', '', 210.532)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="aatu1212",
)
 
mycursor = mydb.cursor()
 
mycursor.execute("SELECT * FROM assesment1.`summary of investment`;")
 
myresult = mycursor.fetchall()
 
for x in myresult:
  print(x)
# Out:
# ('ABC082 ABC Funds Foreign Equity FE  12367', '', '$13.50', '204.175', '$2,002.36', '$2,765.66', '', '$2,756.36')
# ('ABC682 ABC Funds Foreign Equity DSC  12367', '', '$13.50', '924.551', '$10,056.79', '$12,523.62', '', '$12,481.44')
# ('EFG1800 EFG Investments Bond FE  789456', '', '$19.63', '771.708', '$14,956.23', '$15,128.26', '', '$15,148.63')
# ('HIJ1583 HIJ Company Canadian Equity FE 2346543', '', '$17.51', '1,562.450', '$21,562.45', '$27,309.82', '', '$27,358.50')
# ('QRS305 QRS Funds Money Market FE  3214569', '', '$10.00', '210.532', '$2,105.32', '$2,100.10', '', '$2,105.32')
# ('', '', '', '', '$50,683.15', '$59,827.46', '', '$59,850.25')
